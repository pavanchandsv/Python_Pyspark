# %%
import requests

response = requests.get(r'https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow')

# %%
from pyspark.sql import SparkSession
import pandas as pd
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_17680\1819552351.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
j=response.json()['items']

# %%
if response.status_code == 200:
    # Convert JSON response to a dictionary
    data = response.json()
    
    # Extract the items from the response
    items = data['items']
    
    # Create a DataFrame from the items
    df = pd.DataFrame(items)
    
    # Display the DataFrame
    print(df)
else:
    print("Error:", response.status_code)
# Out:
#                                                  tags  \
# 0                         [salesforce-lightning, lwc]
# 1                              [sql, mysql, database]
# 2                                    [ubuntu, nvidia]
# 3                                 [unity-game-engine]
# 4                               [postgresql, catalog]
# 5                            [kernel, imx8, md-crypt]
# 6                          [r, if-statement, ggplot2]
# 7                              [ios, stripe-payments]
# 8                                 [sql-server, t-sql]
# 9                                           [marketo]
# 10                [node.js, azure, docker, profiling]
# 11  [spring-boot, spring-mvc, spring-security, jav...
# 12                  [typescript, typescript-generics]
# 13                         [python-3.x, syntax-error]
# 14                                      [c, pointers]
# 15                                                [r]
# 16                  [python, bash, terminal, ncurses]
# 17                                   [swift, swiftui]
# 18                       [ggplot2, gridextra, gtable]
# 19     [android, xamarin.forms, scrollview, renderer]
# 20                           [security, owasp, hydra]
# 21                            [python, mysql, django]
# 22                                              [git]
# 23                     [python, csv, google-bigquery]
# 24      [java, spring-boot, api, hibernate, endpoint]
# 25                          [c#, .net, razor, blazor]
# 26                               [git, ssh, smartgit]
# 27             [javascript, node.js, vue.js, nuxt.js]
# 28                  [openlayers, geojson, projection]
# 29  [asp.net, f#, minimal-apis, asp.net-minimal-apis]
#
#                                                 owner  is_answered  \
# 0   {'account_id': 28027484, 'reputation': 1, 'use...        False
# 1   {'account_id': 29910672, 'reputation': 1, 'use...        False
# 2   {'account_id': 31155558, 'reputation': 1, 'use...        False
# 3   {'account_id': 12280629, 'reputation': 15, 'us...        False
# 4   {'account_id': 17282558, 'reputation': 31, 'us...        False
# 5   {'account_id': 44262, 'reputation': 43759, 'us...        False
# 6   {'account_id': 16561589, 'reputation': 229, 'u...        False
# 7   {'account_id': 12412753, 'reputation': 413, 'u...        False
# 8   {'account_id': 28677758, 'reputation': 1, 'use...        False
# 9   {'account_id': 25262960, 'reputation': 19, 'us...        False
# 10  {'account_id': 2591690, 'reputation': 3016, 'u...        False
# 11  {'account_id': 2428915, 'reputation': 408, 'us...        False
# 12  {'account_id': 11495533, 'reputation': 47, 'us...        False
# 13  {'account_id': 31154982, 'reputation': 1, 'use...        False
# 14  {'account_id': 31154725, 'reputation': 1, 'use...        False
# 15  {'account_id': 8986118, 'reputation': 507, 'us...        False
# 16  {'account_id': 1838771, 'reputation': 9342, 'u...        False
# 17  {'account_id': 29706899, 'reputation': 1, 'use...        False
# 18  {'account_id': 8429621, 'reputation': 289, 'us...        False
# 19  {'account_id': 3386307, 'reputation': 59, 'use...         True
# 20  {'account_id': 28130400, 'reputation': 1, 'use...         True
# 21  {'account_id': 30688483, 'reputation': 11, 'us...        False
# 22  {'account_id': 3053058, 'reputation': 701, 'us...        False
# 23  {'account_id': 13107292, 'reputation': 21, 'us...        False
# 24  {'account_id': 31155328, 'reputation': 1, 'use...        False
# 25  {'account_id': 31155504, 'reputation': 1, 'use...        False
# 26  {'account_id': 51035, 'reputation': 8422, 'use...         True
# 27  {'account_id': 16376783, 'reputation': 1, 'use...        False
# 28  {'account_id': 29718991, 'reputation': 1, 'use...        False
# 29  {'account_id': 15995965, 'reputation': 21, 'us...         True
#
#     view_count  answer_count  score  last_activity_date  creation_date  \
# 0          218             1      0          1712069932     1699640942
# 1           33             0      0          1712069929     1712065043
# 2            1             0      0          1712069924     1712069924
# 3            2             0      0          1712069920     1712069920
# 4            9             1      0          1712069913     1712068358
# 5            3             0      0          1712069866     1712069866
# 6           16             1      0          1712069863     1712069095
# 7            9             0      0          1712069860     1712069609
# 8           15             1      0          1712069849     1712069428
# 9           17             1      0          1712069833     1708001393
# 10          19             1      0          1712069817     1711110239
# 11           4             0      0          1712069816     1712069816
# 12          31             0      0          1712069813     1712056150
# 13           5             0      0          1712069807     1712069807
# 14          55             1     -3          1712069791     1712068165
# 15          32             3      2          1712069785     1712066769
# 16          21             0      0          1712069785     1712065654
# 17          55             1      0          1712069782     1711904530
# 18           5             0      0          1712069780     1712068785
# 19        2588             4      4          1712069767     1516214975
# 20         798             1      0          1712069767     1679846586
# 21           8             0      0          1712069742     1712069543
# 22          13             0      0          1712069742     1712068169
# 23          46             4      2          1712069737     1711963520
# 24           4             0      0          1712069733     1712069733
# 25           4             0      0          1712069732     1712069732
# 26       43313             6     18          1712069728     1326114153
# 27           7             0      0          1712069721     1712069721
# 28           5             0      0          1712069721     1712069721
# 29          17             1      2          1712069719     1712059602
#
#     last_edit_date  question_id content_license  \
# 0     1.699642e+09     77462152    CC BY-SA 4.0
# 1     1.712070e+09     78261723    CC BY-SA 4.0
# 2              NaN     78262211    CC BY-SA 4.0
# 3              NaN     78262210    CC BY-SA 4.0
# 4              NaN     78262035    CC BY-SA 4.0
# 5              NaN     78262208    CC BY-SA 4.0
# 6              NaN     78262126    CC BY-SA 4.0
# 7     1.712070e+09     78262183    CC BY-SA 4.0
# 8     1.712070e+09     78262165    CC BY-SA 4.0
# 9              NaN     78000913    CC BY-SA 4.0
# 10             NaN     78206218    CC BY-SA 4.0
# 11             NaN     78262205    CC BY-SA 4.0
# 12    1.712070e+09     78260841    CC BY-SA 4.0
# 13             NaN     78262203    CC BY-SA 4.0
# 14    1.712070e+09     78262019    CC BY-SA 4.0
# 15    1.712068e+09     78261876    CC BY-SA 4.0
# 16    1.712070e+09     78261786    CC BY-SA 4.0
# 17    1.712069e+09     78252152    CC BY-SA 4.0
# 18    1.712070e+09     78262087    CC BY-SA 4.0
# 19             NaN     48308036    CC BY-SA 3.0
# 20    1.700570e+09     75848895    CC BY-SA 4.0
# 21    1.712070e+09     78262177    CC BY-SA 4.0
# 22    1.712070e+09     78262020    CC BY-SA 4.0
# 23    1.712070e+09     78254631    CC BY-SA 4.0
# 24             NaN     78262199    CC BY-SA 4.0
# 25             NaN     78262198    CC BY-SA 4.0
# 26             NaN      8788813    CC BY-SA 3.0
# 27             NaN     78262197    CC BY-SA 4.0
# 28             NaN     78262196    CC BY-SA 4.0
# 29             NaN     78261194    CC BY-SA 4.0
#
#                                                  link  \
# 0   https://stackoverflow.com/questions/77462152/s...
# 1   https://stackoverflow.com/questions/78261723/s...
# 2   https://stackoverflow.com/questions/78262211/n...
# 3   https://stackoverflow.com/questions/78262210/d...
# 4   https://stackoverflow.com/questions/78262035/w...
# 5   https://stackoverflow.com/questions/78262208/a...
# 6   https://stackoverflow.com/questions/78262126/h...
# 7   https://stackoverflow.com/questions/78262183/t...
# 8   https://stackoverflow.com/questions/78262165/f...
# 9   https://stackoverflow.com/questions/78000913/h...
# 10  https://stackoverflow.com/questions/78206218/n...
# 11  https://stackoverflow.com/questions/78262205/t...
# 12  https://stackoverflow.com/questions/78260841/t...
# 13  https://stackoverflow.com/questions/78262203/p...
# 14  https://stackoverflow.com/questions/78262019/w...
# 15  https://stackoverflow.com/questions/78261876/e...
# 16  https://stackoverflow.com/questions/78261786/h...
# 17  https://stackoverflow.com/questions/78252152/h...
# 18  https://stackoverflow.com/questions/78262087/h...
# 19  https://stackoverflow.com/questions/48308036/x...
# 20  https://stackoverflow.com/questions/75848895/h...
# 21  https://stackoverflow.com/questions/78262177/h...
# 22  https://stackoverflow.com/questions/78262020/g...
# 23  https://stackoverflow.com/questions/78254631/h...
# 24  https://stackoverflow.com/questions/78262199/s...
# 25  https://stackoverflow.com/questions/78262198/s...
# 26  https://stackoverflow.com/questions/8788813/sm...
# 27  https://stackoverflow.com/questions/78262197/h...
# 28  https://stackoverflow.com/questions/78262196/h...
# 29  https://stackoverflow.com/questions/78261194/d...
#
#                                                 title  accepted_answer_id
# 0   Salesforce lightning datatable not displaying ...                 NaN
# 1                     Strange behaviour of MySQL DBMS                 NaN
# 2         Nvidia installation problem in ubuntu 22.04                 NaN
# 3   Dynamic Grid Borders and “Carved” Effect for a...                 NaN
# 4   What is OID of the system catalog in PostgreSQ...                 NaN
# 5   Attempting to use the imx8 caam causes &quot;d...                 NaN
# 6            How to use ifelse inside aes in ggplot2?                 NaN
# 7   The certificate for this server is invalid. Er...                 NaN
# 8   Filling in NULL values from a column with data...                 NaN
# 9   How to use Marketo template meta variable into...                 NaN
# 10  Node.js --cpu-prof flag: Failed to convert CPU...                 NaN
# 11  The simplest spring security config breaks my ...                 NaN
# 12     Two equal types should be mutually assignable?                 NaN
# 13  Python cmd string with import and if statement...                 NaN
# 14                    what is *(*(*p))) pointer in C?                 NaN
# 15  efficient conversion of non-repeating sequence...                 NaN
# 16  How to conditionally clear script output after...                 NaN
# 17  How to make a scroll view of 9 images in a for...                 NaN
# 18  how to edit ggplot&#39;s legend words using a ...                 NaN
# 19      Xamarin Forms, ScrollView ScrollToAsync Speed                 NaN
# 20                        Hydra with OWASP juice-shop          75953563.0
# 21  How can I optimize raw queries to a MySQL in d...                 NaN
# 22      git log %d directive expands after truncation                 NaN
# 23  How do I move the next line (line 1125) separa...                 NaN
# 24   SpringBoot Hibernate Select returning empty data                 NaN
# 25           Showing blazor component on button click                 NaN
# 26           SmartGit won&#39;t authenticate with ssh           8789131.0
# 27  How to add Google Ads Manager Ads units (Banne...                 NaN
# 28  How to transform geoJSON 31983 into 4326 in Op...                 NaN
# 29  Dynamically Creating a Func&lt;&gt; Delegate i...                 NaN
