# %%
import psycopg2
import pandas as pd
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_8256\979458548.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
try: 
    conn = psycopg2.connect("host=localhost port=5433 dbname=postgres user=postgres password=password")
    print("connected to DB)")
except psycopg2.Error as e: 
    print("Error: Could not make connection to the Postgres database")
    print(e)
# Out:
# connected to DB)

# %%
cur=conn.cursor()

# %%
cur.execute("SELECT * FROM employee_2_scd")

# %%
rows=cur.fetchall()

# %%
df=pd.DataFrame(rows,columns=["Rec_id",
"Employee_Id",
"firstName",
"lastName",
"email",
"phone",
"hire_e",
"job_id",
"salary",
"Com_pct",
"manager_id",
"dept_id",
"Is_Active",
"Create_timestamp",
"update_timestamp",
"end_timestamp"])

# %%
df.describe()
# Out:
#            Rec_id  Employee_Id        salary  manager_id     dept_id  \
# count  107.000000   107.000000    107.000000  106.000000  106.000000
# mean    54.000000   153.000000   6461.831776  124.764151   63.207547
# min      1.000000   100.000000   2100.000000  100.000000   10.000000
# 25%     27.500000   126.500000   3100.000000  108.000000   50.000000
# 50%     54.000000   153.000000   6200.000000  122.000000   50.000000
# 75%     80.500000   179.500000   8900.000000  145.000000   80.000000
# max    107.000000   206.000000  24000.000000  205.000000  110.000000
# std     31.032241    31.032241   3909.579731   20.315395   20.910110
#
#                     Create_timestamp
# count                            107
# mean   2024-03-30 09:27:50.000000768
# min              2024-03-30 09:27:50
# 25%              2024-03-30 09:27:50
# 50%              2024-03-30 09:27:50
# 75%              2024-03-30 09:27:50
# max              2024-03-30 09:27:50
# std                              NaN

# %%
df.fillna(value=999)
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_20492\2538418135.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(value=999)
#      Rec_id  Employee_Id  firstName lastName     email         phone  \
# 0         1          100     Steven     King     SKING  515.123.4567
# 1         2          101      Neena  Kochhar  NKOCHHAR  515.123.4568
# 2         3          102        Lex  De Haan   LDEHAAN  515.123.4569
# 3         4          103  Alexander   Hunold   AHUNOLD  590.423.4567
# 4         5          104      Bruce    Ernst    BERNST  590.423.4568
# ..      ...          ...        ...      ...       ...           ...
# 102     103          202        Pat      Fay      PFAY  603.123.6666
# 103     104          203      Susan   Mavris   SMAVRIS  515.123.7777
# ...

# %%
cur.close
# Out:
# <function cursor.close>

# %%
cur.execute(" CREATE TABLE IF NOT EXISTS public.scd_2 ( Rec_id integer NOT NULL, Employee_Id integer,firstName character varying(20)  ,lastName character varying(20)  ,email character varying(30)  ,phone character varying(20)  ,hire_date date,job_id character varying(30)  ,salary integer,Com_pct character varying(20)  ,manager_id integer,dept_id integer,Is_Active character(1)  ,Create_timestamp timestamp without time zone,update_timestamp timestamp without time zone,end_timestamp timestamp without time zone,CONSTRAINT rec_24_pkey PRIMARY KEY (Rec_id))")

# %%
cur.execute("insert into public.scd_2 select * from  employee_2_scd")

# %%
conn.commit()
